# %%
# %config IPCompleter.greedy=True

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')

# %%
combats = pd.read_csv('combats.csv')
combats.head()
# combats.iloc[3412]
# Out:
#    First_pokemon  Second_pokemon  Winner
# 0            266             298     298
# 1            702             701     701
# 2            191             668     668
# 3            237             683     683
# 4            151             231     151

# %%
pokemons = pd.read_csv('pokemon.csv')
pokemons[pokemons['#'].isin(['298','266'])]
# Out:
#        #      Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 265  266  Larvitar   Rock  Ground  50      64       50       45       50
# 297  298   Nuzleaf  Grass    Dark  70      70       40       60       40
#
#      Speed  Generation  Legendary
# 265     41           2      False
# 297     60           3      False

# %%
tests = pd.read_csv('tests.csv')
tests.sample(10)
# Out:
#       First_pokemon  Second_pokemon
# 5369            674             125
# 8051            456             509
# 1075            149             168
# 982             648             588
# 1895            613             696
# 990             413             339
# 6375            677             540
# 2309            426             321
# 9085            402             534
# 4496            295             121

# %%
poke_types =pokemons.groupby(pokemons['Type 1']).count()
poke_types
# Out:
#             #  Name  Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Type 1
# Bug        69    69      52   69      69       69       69       69     69
# Dark       31    31      21   31      31       31       31       31     31
# Dragon     32    32      21   32      32       32       32       32     32
# Electric   44    44      17   44      44       44       44       44     44
# Fairy      17    17       2   17      17       17       17       17     17
# Fighting   27    26       7   27      27       27       27       27     27
# Fire       52    52      24   52      52       52       52       52     52
# Flying      4     4       2    4       4        4        4        4      4
# Ghost      32    32      22   32      32       32       32       32     32
# Grass      70    70      37   70      70       70       70       70     70
# Ground     32    32      19   32      32       32       32       32     32
# ...

# %%
pokemons[pokemons['Legendary']==False].sort_values('Sp. Atk', ascending=False)
# Out:
#        #                   Name    Type 1    Type 2   HP  Attack  Defense  \
# 71    72          Mega Alakazam   Psychic       NaN   55      50       65
# 102  103            Mega Gengar     Ghost    Poison   60      65       80
# 196  197          Mega Ampharos  Electric    Dragon   90      95      105
# 306  307         Mega Gardevoir   Psychic     Fairy   68      85       65
# 8      9       Mega Charizard Y      Fire    Flying   78     104       78
# 750  751  Aegislash Blade Forme     Steel     Ghost   60     150       50
# 275  276          Mega Sceptile     Grass    Dragon   70     110       75
# 354  355          Mega Camerupt      Fire    Ground   70     120      100
# 670  671             Chandelure     Ghost      Fire   60      55       90
# 248  249          Mega Houndoom      Dark      Fire   75      90       90
# 498  499           Mega Lucario  Fighting     Steel   70     145       88
# 616  617    Darmanitan Zen Mode      Fire   Psychic  105      30      105
# ...

# %%
pokemons.columns
plt.figure(figsize=(15,10))
sns.set_style('whitegrid')
# water_pokes = pokemons[pokemons['Type 1'] == 'Flying']
sns.countplot(x='Type 1', hue='Type 2', data=pokemons, dodge=False)

# %%
plt.figure(figsize=(15,8))
sns.set_style('darkgrid')
sns.countplot(x='Type 2', data=pokemons, color='b')

# %%
water_pokes = pokemons[pokemons['Type 1'] == 'Grass'][pokemons['Legendary']==True]
water_pokes
# Out:
#        #                Name Type 1    Type 2   HP  Attack  Defense  Sp. Atk  \
# 550  551  Shaymin Land Forme  Grass       NaN  100     100      100      100
# 551  552   Shaymin Sky Forme  Grass    Flying  100     103       75      120
# 701  702            Virizion  Grass  Fighting   91      90       72       90
#
#      Sp. Def  Speed  Generation  Legendary
# 550      100    100           4       True
# 551       75    127           4       True
# 701      129    108           5       True

# %%
plt.figure(figsize=(15,10))
sns.set_style('darkgrid')
sns.countplot(x='Type 1', hue='Legendary', data=pokemons,dodge=False)

# %%
plt.figure(figsize=(15,8))
sns.set_style('darkgrid')
sns.barplot(x='Type 1', y='Speed',data=pokemons, color='c' )
